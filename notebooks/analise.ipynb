# %%
import pandas as pd

df_perfil = pd.read_parquet("../data/raw/england_premier_league_25_26_perfil.parquet")

print("Formato:", df_perfil.shape)
df_perfil.head(10)
# Out:
# Formato: (537, 12)
#         id             nome primeiro_nome ultimo_nome posicao  \
# 0   839956   Erling Haaland        Erling     Haaland       F
# 1   159665    Mohamed Salah       Mohamed       Salah       M
# 2   982780      Cole Palmer           NaN         NaN       M
# 3   288205  Bruno Fernandes         Bruno   Fernandes       M
# 4   873554    Omar Marmoush          Omar    Marmoush       F
# 5   804508  Viktor Gyökeres        Viktor    Gyokeres       F
# 6  1597265          Estêvão       Estêvão         NaN       M
# 7   934235      Bukayo Saka        Bukayo        Saka       F
# 8   859765       Phil Foden          Phil       Foden       M
# 9  1019322    Florian Wirtz           NaN         NaN       M
#
#   posicoes_detalhadas            data_nascimento  altura pe_preferido  \
# 0                  ST  2000-07-21T00:00:00+00:00   194.0         Left
# 1                  RW  1992-06-15T00:00:00+00:00   175.0         Left
# ...
